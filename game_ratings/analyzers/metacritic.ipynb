# %%
import os
import pandas as pd

pd.options.display.max_rows = 1000
home = os.path.expanduser('~')
path = f'{home}/Documents'
df = pd.read_csv(f'{path}/metacritic.csv').set_index(['date'])
df = df[df.score >= 90]
df.sort_index().to_csv(f'{path}/metacritic-must-play.csv')
df.groupby(['score']).count().sort_index(ascending=False)
# Out:
#        title  platform  mustplay
# score
# 99         1         1         1
# 98         5         5         5
# 97        18        18        18
# 96        21        21        21
# 95        21        21        21
# 94        48        48        48
# 93        70        70        70
# 92        87        87        87
# 91       120       120       120
# 90       147       147       147
